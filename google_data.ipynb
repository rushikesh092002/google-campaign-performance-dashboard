# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/GoogleAds_DataAnalytics_Sales_Uncleaned.csv')

# %%
df
# Out:
#       Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0     A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1     A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2     A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3     A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4     A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
# ...     ...                    ...     ...          ...      ...    ...
# 2595  A3595    DataAnalyticsCourse    88.0       5344.0  $242.07   17.0
# 2596  A3596    DataAnalyticsCourse   154.0       3211.0  $248.28   14.0
# 2597  A3597    Data Anlytics Corse   113.0       3808.0  $233.25   18.0
# 2598  A3598   Data Analytics Corse   196.0       5853.0  $220.13   16.0
# 2599  A3599   Data Analytics Corse     NaN       5453.0      NaN   12.0
#
#       Conversions  Conversion Rate Sale_Amount     Ad_Date   Location  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ad_ID            2600 non-null   object
#  1   Campaign_Name    2600 non-null   object
#  2   Clicks           2488 non-null   float64
#  3   Impressions      2546 non-null   float64
#  4   Cost             2503 non-null   object
#  5   Leads            2552 non-null   float64
#  6   Conversions      2526 non-null   float64
#  7   Conversion Rate  1974 non-null   float64
#  8   Sale_Amount      2461 non-null   object
#  9   Ad_Date          2600 non-null   object
#  10  Location         2600 non-null   object
#  11  Device           2600 non-null   object
#  12  Keyword          2600 non-null   object
# dtypes: float64(5), object(8)
# memory usage: 264.2+ KB

# %%
df.isnull().sum()
# Out:
# Ad_ID                0
# Campaign_Name        0
# Clicks             112
# Impressions         54
# Cost                97
# Leads               48
# Conversions         74
# Conversion Rate    626
# Sale_Amount        139
# Ad_Date              0
# Location             0
# Device               0
# Keyword              0
# dtype: int64

# %%
df.head()
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
#
#    Conversions  Conversion Rate Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0            0.058       $1892  2024-11-16  hyderabad  desktop
# 1          8.0            0.046       $1679  20-11-2024  hyderabad   mobile
# 2          9.0              NaN       $1624  2024/11/16  hyderabad  Desktop
# 3          6.0              NaN       $1225  2024-11-26  HYDERABAD   tablet
# 4          8.0              NaN       $1091  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ad_ID            2600 non-null   object
#  1   Campaign_Name    2600 non-null   object
#  2   Clicks           2488 non-null   float64
#  3   Impressions      2546 non-null   float64
#  4   Cost             2503 non-null   object
#  5   Leads            2552 non-null   float64
#  6   Conversions      2526 non-null   float64
#  7   Conversion Rate  1974 non-null   float64
#  8   Sale_Amount      2461 non-null   object
#  9   Ad_Date          2600 non-null   object
#  10  Location         2600 non-null   object
#  11  Device           2600 non-null   object
#  12  Keyword          2600 non-null   object
# dtypes: float64(5), object(8)
# memory usage: 264.2+ KB

# %%
df['Cost'] = df['Cost'].replace('[\$,]', '', regex=True).astype(float)

# %%
df['Sale_Amount'] = df['Sale_Amount'].replace('[\$,]', '', regex=True).astype(float)

# %%
df.head()
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions    Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0  195.90   30.0
#
#    Conversions  Conversion Rate  Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0            0.058       1892.0  2024-11-16  hyderabad  desktop
# 1          8.0            0.046       1679.0  20-11-2024  hyderabad   mobile
# 2          9.0              NaN       1624.0  2024/11/16  hyderabad  Desktop
# 3          6.0              NaN       1225.0  2024-11-26  HYDERABAD   tablet
# 4          8.0              NaN       1091.0  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ad_ID            2600 non-null   object
#  1   Campaign_Name    2600 non-null   object
#  2   Clicks           2488 non-null   float64
#  3   Impressions      2546 non-null   float64
#  4   Cost             2503 non-null   float64
#  5   Leads            2552 non-null   float64
#  6   Conversions      2526 non-null   float64
#  7   Conversion Rate  1974 non-null   float64
#  8   Sale_Amount      2461 non-null   float64
#  9   Ad_Date          2600 non-null   object
#  10  Location         2600 non-null   object
#  11  Device           2600 non-null   object
#  12  Keyword          2600 non-null   object
# dtypes: float64(7), object(6)
# memory usage: 264.2+ KB

# %%
df['Conversion Rate (Recalc)'] = df['Conversions'] / df['Clicks'].replace(0, np.nan)

df['Conversion Rate'] = df['Conversion Rate'].fillna(df['Conversion Rate (Recalc)'])
df.drop(columns=['Conversion Rate (Recalc)'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ad_ID            2600 non-null   object
#  1   Campaign_Name    2600 non-null   object
#  2   Clicks           2488 non-null   float64
#  3   Impressions      2546 non-null   float64
#  4   Cost             2503 non-null   float64
#  5   Leads            2552 non-null   float64
#  6   Conversions      2526 non-null   float64
#  7   Conversion Rate  2447 non-null   float64
#  8   Sale_Amount      2461 non-null   float64
#  9   Ad_Date          2600 non-null   object
#  10  Location         2600 non-null   object
#  11  Device           2600 non-null   object
#  12  Keyword          2600 non-null   object
# dtypes: float64(7), object(6)
# memory usage: 264.2+ KB

# %%
missing_data = df.isnull().sum().sort_values(ascending=False)
print(missing_data)
# Out:
# Conversion Rate    153
# Sale_Amount        139
# Clicks             112
# Cost                97
# Conversions         74
# Impressions         54
# Leads               48
# Campaign_Name        0
# Ad_ID                0
# Ad_Date              0
# Location             0
# Device               0
# Keyword              0
# dtype: int64

# %%
df['Conversion Rate'] = df['Conversion Rate'].fillna(df['Conversions'] / df['Clicks'].replace(0, np.nan))

# %%
missing_data = df.isnull().sum().sort_values(ascending=False)
print(missing_data)
# Out:
# Conversion Rate    153
# Sale_Amount        139
# Clicks             112
# Cost                97
# Conversions         74
# Impressions         54
# Leads               48
# Campaign_Name        0
# Ad_ID                0
# Ad_Date              0
# Location             0
# Device               0
# Keyword              0
# dtype: int64

# %%
df = df.dropna(subset=['Conversions'])

# %%
avg_rev_per_conv = df['Sale_Amount'].sum() / df['Conversions'].sum()
avg_cpc = df['Cost'].sum() / df['Clicks'].sum()
avg_ctr = df['Clicks'].sum() / df['Impressions'].sum()

# %%
df['Sale_Amount'] = df['Sale_Amount'].fillna(df['Conversions'] * avg_rev_per_conv)
df['Cost'] = df['Cost'].fillna(df['Clicks'] * avg_cpc)
df['Impressions'] = df['Impressions'].fillna(df['Clicks'] / avg_ctr)
# Out:
# /tmp/ipython-input-20-545056447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sale_Amount'] = df['Sale_Amount'].fillna(df['Conversions'] * avg_rev_per_conv)
# /tmp/ipython-input-20-545056447.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cost'] = df['Cost'].fillna(df['Clicks'] * avg_cpc)
# /tmp/ipython-input-20-545056447.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
print(df.isnull().sum())
# Out:
# Ad_ID               0
# Campaign_Name       0
# Clicks              6
# Impressions         3
# Cost                6
# Leads              45
# Conversions         0
# Conversion Rate    90
# Sale_Amount         0
# Ad_Date             0
# Location            0
# Device              0
# Keyword             0
# dtype: int64

# %%
df['Clicks'] = df['Clicks'].fillna(df['Cost'] / avg_cpc)
# Out:
# /tmp/ipython-input-22-2958862434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Clicks'] = df['Clicks'].fillna(df['Cost'] / avg_cpc)

# %%
df['Impressions'] = df['Impressions'].fillna(df['Impressions'].median())
# Out:
# /tmp/ipython-input-24-4175920608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Impressions'] = df['Impressions'].fillna(df['Impressions'].median())

# %%
df['Conversion Rate'] = df['Conversion Rate'].fillna(df['Conversion Rate'].mean())
# Out:
# /tmp/ipython-input-25-2808189212.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Conversion Rate'] = df['Conversion Rate'].fillna(df['Conversion Rate'].mean())

# %%
print(df.isnull().sum())
# Out:
# Ad_ID               0
# Campaign_Name       0
# Clicks              6
# Impressions         0
# Cost                0
# Leads              45
# Conversions         0
# Conversion Rate     0
# Sale_Amount         0
# Ad_Date             0
# Location            0
# Device              0
# Keyword             0
# dtype: int64

# %%
df['Cost']=df['Cost'].fillna(df['Cost'].mean())
# Out:
# /tmp/ipython-input-28-4057378687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cost']=df['Cost'].fillna(df['Cost'].mean())

# %%
df.head()
# Out:
#    Ad_ID          Campaign_Name  Clicks  Impressions    Cost  Leads  \
# 0  A1000    DataAnalyticsCourse   104.0       4498.0  231.88   14.0
# 1  A1001    DataAnalyticsCourse   173.0       5107.0  216.84   10.0
# 2  A1002    Data Anlytics Corse    90.0       4544.0  203.66   26.0
# 3  A1003  Data Analytcis Course   142.0       3185.0  237.66   17.0
# 4  A1004   Data Analytics Corse   156.0       3361.0  195.90   30.0
#
#    Conversions  Conversion Rate  Sale_Amount     Ad_Date   Location   Device  \
# 0          7.0         0.058000       1892.0  2024-11-16  hyderabad  desktop
# 1          8.0         0.046000       1679.0  20-11-2024  hyderabad   mobile
# 2          9.0         0.100000       1624.0  2024/11/16  hyderabad  Desktop
# 3          6.0         0.042254       1225.0  2024-11-26  HYDERABAD   tablet
# 4          8.0         0.051282       1091.0  2024-11-22  hyderabad  desktop
#
#                   Keyword
# 0    learn data analytics
# 1   data analytics course
# ...

# %%
# Calculate floor mean and convert to float with .0
mean_val = np.floor(df['Leads'].mean())
clean_val = float(mean_val)

# %%
clean_val
# Out:
# 20.0

# %%
# Fill missing values with that
df['Leads'] = df['Leads'].fillna(clean_val)
# Out:
# /tmp/ipython-input-34-2825104824.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Leads'] = df['Leads'].fillna(clean_val)

# %%
df.isna().sum()
# Out:
# Ad_ID              0
# Campaign_Name      0
# Clicks             6
# Impressions        0
# Cost               0
# Leads              0
# Conversions        0
# Conversion Rate    0
# Sale_Amount        0
# Ad_Date            0
# Location           0
# Device             0
# Keyword            0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# /tmp/ipython-input-38-1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.describe()
# Out:
#             Clicks  Impressions         Cost        Leads  Conversions  \
# count  2520.000000  2520.000000  2520.000000  2520.000000  2520.000000
# mean    138.878112  4530.794349   215.204623    20.003571     6.517063
# std      34.054860   874.370497    22.102841     5.970118     2.271670
# min      80.000000  2667.626348   124.597940    10.000000     3.000000
# 25%     111.000000  3777.750000   197.235000    15.000000     5.000000
# 50%     139.000000  4522.500000   215.600000    20.000000     7.000000
# 75%     167.250000  5288.500000   233.422500    25.000000     9.000000
# max     199.000000  6635.720542   309.937377    30.000000    10.000000
#
#        Conversion Rate  Sale_Amount
# count      2520.000000  2520.000000
# mean          0.049443  1494.449561
# std           0.020293   302.781319
# min           0.015000   652.659501
# 25%           0.035000  1241.000000
# 50%           0.047619  1506.000000
# 75%           0.058000  1740.425336
# ...

# %%
df['CTR'] = df['Clicks'] / df['Impressions']
df['CPC'] = df['Cost'] / df['Clicks'].replace(0, np.nan)
df['CPA'] = df['Cost'] / df['Conversions'].replace(0, np.nan)
# Out:
# /tmp/ipython-input-45-4026599363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CTR'] = df['Clicks'] / df['Impressions']
# /tmp/ipython-input-45-4026599363.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CPC'] = df['Cost'] / df['Clicks'].replace(0, np.nan)
# /tmp/ipython-input-45-4026599363.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Out:
#       Ad_ID          Campaign_Name  Clicks  Impressions    Cost  Leads  \
# 0     A1000    DataAnalyticsCourse   104.0       4498.0  231.88   14.0
# 1     A1001    DataAnalyticsCourse   173.0       5107.0  216.84   10.0
# 2     A1002    Data Anlytics Corse    90.0       4544.0  203.66   26.0
# 3     A1003  Data Analytcis Course   142.0       3185.0  237.66   17.0
# 4     A1004   Data Analytics Corse   156.0       3361.0  195.90   30.0
# ...     ...                    ...     ...          ...     ...    ...
# 2594  A3594    Data Anlytics Corse    99.0       4446.0  233.53   11.0
# 2595  A3595    DataAnalyticsCourse    88.0       5344.0  242.07   17.0
# 2596  A3596    DataAnalyticsCourse   154.0       3211.0  248.28   14.0
# 2597  A3597    Data Anlytics Corse   113.0       3808.0  233.25   18.0
# 2598  A3598   Data Analytics Corse   196.0       5853.0  220.13   16.0
#
#       Conversions  Conversion Rate  Sale_Amount     Ad_Date   Location  \
# ...

# %% [markdown]
# ### ✅ 1. Total Clicks by Campaign ###

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.barplot(x='Campaign_Name', y='Clicks', data=df, estimator='sum', ci=None)
plt.xticks(rotation=45)
plt.title('Total Clicks by Campaign')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-48-3304981966.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Campaign_Name', y='Clicks', data=df, estimator='sum', ci=None)

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Impressions', y='Clicks', hue='Campaign_Name', data=df)
plt.title('Impressions vs Clicks')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Cost'], bins=20, kde=True)
plt.title('Cost Distribution')
plt.xlabel('Cost')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Device', y='Leads', data=df)
plt.title('Lead Distribution by Device')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='Campaign_Name', y='Conversion Rate', data=df, estimator='mean', ci=None)
plt.xticks(rotation=45)
plt.title('Average Conversion Rate by Campaign')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-52-3781942785.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Campaign_Name', y='Conversion Rate', data=df, estimator='mean', ci=None)

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
device_conversions = df.groupby('Device')['Conversions'].sum()
device_conversions.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.ylabel('')
plt.title('Total Conversions by Device')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df[['Leads', 'Conversions']])
plt.title('Leads vs Conversions Trend')
plt.show()

# %%
df['CTR'] = df['Clicks'] / df['Impressions']
plt.figure(figsize=(8, 6))
sns.histplot(df['CTR'], kde=True)
plt.title('Click Through Rate Distribution')
plt.show()
# Out:
# /tmp/ipython-input-57-3676660394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CTR'] = df['Clicks'] / df['Impressions']

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Campaign_Name', y='Cost', data=df, color='red', label='Cost')
sns.barplot(x='Campaign_Name', y='Sale_Amount', data=df, color='green', label='Sales')
plt.xticks(rotation=45)
plt.title('Cost vs Sales by Campaign')
plt.legend()
plt.tight_layout()
plt.show()

# %%
df.to_csv("cleaned_marketing_data.csv", index=False)
